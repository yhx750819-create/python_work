# %%
r = 25
area = 3.1415 * r * r
print(area)

# %%
Tempreture = input
if Tempreture[-1] in ['F', 'f']:
    C = (eval(Tempreture[0:-1]) - 32) / 1.8
    print("转换后的温度是{:.2f}C".format(C))
elif Tempreture[-1] in ['C', 'c']:
    C = eval(Tempreture[0:-1]) * 1.8 + 32 
    print("转换后的温度是{:.2f}F".format(C))
else:
    print("输入格式有误")
